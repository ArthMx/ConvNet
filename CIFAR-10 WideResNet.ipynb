# %% [markdown]
# # Wide Residual Net for the CIFAR-10 dataset
#
# In this notebook, I will implement a wide residual network, inspired by the paper :
# - Sergey Zagoruyko & Nikos Komodakis, 2017, Wide Residual Networks
#
# In this paper, the effects of depth vs width have been studied for residual networks. The conclusion is that increasing the width and limiting the depth of the residual networks presented in *Deep Residual Learning for Image Recognition* can significantly improve performance while reducing training time.

# %%
import numpy as np
import keras
from keras.layers import Input, Activation, Conv2D, AvgPool2D
from keras.layers import Dense, Flatten, BatchNormalization, Dropout
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from keras.callbacks import ModelCheckpoint
import time
# Out:
# /home/arthur/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Data Preparation

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('X shape :', x_train.shape)
print(len(x_train), 'train samples')
print(len(x_test), 'test samples')
# Out:
# X shape : (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_train_mean)/x_train_std

n_y = 10
y_train = keras.utils.to_categorical(y_train, n_y)
y_test = keras.utils.to_categorical(y_test, n_y)

# %% [markdown]
# # Model

# %%
l2_reg = keras.regularizers.l2(0.0005)

def residual_unit(x_input, filters, stride=1, regularizer=l2_reg, dropout_rate=None):
    x = Conv2D(filters, kernel_size=(3,3), padding='same', use_bias=False, 
               strides=stride, kernel_regularizer=regularizer)(x_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    
    x = Conv2D(filters, kernel_size=(3,3), padding='same', use_bias=False, 
               kernel_regularizer=regularizer)(x)
    x = BatchNormalization()(x)
    
    if stride!=1:
        x_input = AvgPool2D(pool_size=stride)(x_input)
        x_input = Conv2D(filters, kernel_size=(1,1), use_bias=False, 
                         kernel_regularizer=regularizer)(x_input)
        x_input = BatchNormalization()(x_input)
    
    x_res = keras.layers.add([x, x_input])
    x_res = BatchNormalization()(x_res)
    x_out = Activation('relu')(x_res)
    
    return x_out

# %%
def WideResidualNet(k=1, n=3, dropout_rate=None, n_map=16, regularizer=l2_reg):
    n_map = k*16
    
    x_input = Input(shape=(32, 32, 3))

    x = Conv2D(n_map, (3,3), padding='same', use_bias=False, 
               kernel_regularizer=regularizer)(x_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    
    # Block 1
    for i in range(n):
        x = residual_unit(x, n_map, dropout_rate=dropout_rate)
    
    # Block 2
    x = residual_unit(x, n_map*2, stride=2, regularizer=l2_reg, dropout_rate=dropout_rate)
    for i in range(n-1):
        x = residual_unit(x, n_map*2, regularizer=l2_reg, dropout_rate=dropout_rate)
    
    # Block 3
    x = residual_unit(x, n_map*4, stride=2, regularizer=l2_reg, dropout_rate=dropout_rate)
    for i in range(n-1):
        x = residual_unit(x, n_map*4, regularizer=l2_reg, dropout_rate=dropout_rate)

    x = AvgPool2D((8,8))(x)
    x = Flatten()(x)
    output = Dense(10, activation='softmax')(x)

    return Model(x_input, output)

# %%
model = WideResidualNet(k=2, n=2, dropout_rate=0.3)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9216        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9216        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           batch_normalization_3[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9216        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9216        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           batch_normalization_6[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 16, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36864       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   2048        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 64)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36864       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           batch_normalization_13[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    73728       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 128)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 8, 8, 64)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    147456      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    8192        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 128)    512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147456      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 128)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147456      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           batch_normalization_20[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 128)    512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 128)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        flatten_1[0][0]
# ==================================================================================================
# Total params: 700,650
# Trainable params: 697,514
# Non-trainable params: 3,136
# __________________________________________________________________________________________________

# %% [markdown]
# # Model training

# %%
# Set optimizer to train the model
optimizer = keras.optimizers.SGD(0.1, momentum=0.9, nesterov=True)
model.compile(optimizer, keras.losses.categorical_crossentropy, ['accuracy'])

# Data augmentation
shift = 4/32
generator = ImageDataGenerator(width_shift_range=shift, height_shift_range=shift, 
                               horizontal_flip=True)

batch_size = 64
n_steps = x_train.shape[0]//batch_size # training steps per epoch


save_path = './Model_trained/WideResNet20_cifar10.h5'
ckeckpoint = ModelCheckpoint(save_path, monitor='val_acc', save_best_only=True, verbose=1)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.1), patience=5, 
                                              min_delta=0.01, min_lr=1e-6)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_acc', patience=20)

t0 = time.time()
model.fit_generator(generator.flow(x_train, y_train, batch_size=batch_size), steps_per_epoch=n_steps, 
                    epochs=200, validation_data=(x_test, y_test), 
                    callbacks=[ckeckpoint, reduce_lr, early_stopping])
print('Total training time : %.3f s' %(time.time()-t0))
# Out:
# Epoch 1/200
# 781/781 [==============================] - 44s 57ms/step - loss: 1.8010 - acc: 0.4691 - val_loss: 2.1780 - val_acc: 0.4260
#
# Epoch 00001: val_acc improved from -inf to 0.42600, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 2/200
# 781/781 [==============================] - 41s 53ms/step - loss: 1.3381 - acc: 0.6240 - val_loss: 1.3038 - val_acc: 0.6536
#
# Epoch 00002: val_acc improved from 0.42600 to 0.65360, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 3/200
# 781/781 [==============================] - 41s 53ms/step - loss: 1.2285 - acc: 0.6750 - val_loss: 1.7124 - val_acc: 0.5450
#
# Epoch 00003: val_acc did not improve from 0.65360
# Epoch 4/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1855 - acc: 0.7023 - val_loss: 1.4007 - val_acc: 0.6549
#
# Epoch 00004: val_acc improved from 0.65360 to 0.65490, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 5/200
# 781/781 [==============================] - 40s 51ms/step - loss: 1.1706 - acc: 0.7152 - val_loss: 1.5622 - val_acc: 0.6343
#
# Epoch 00005: val_acc did not improve from 0.65490
# Epoch 6/200
# 781/781 [==============================] - 40s 51ms/step - loss: 1.1683 - acc: 0.7242 - val_loss: 1.7224 - val_acc: 0.6234
#
# Epoch 00006: val_acc did not improve from 0.65490
# Epoch 7/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1604 - acc: 0.7316 - val_loss: 1.2771 - val_acc: 0.6922
#
# Epoch 00007: val_acc improved from 0.65490 to 0.69220, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 8/200
# 781/781 [==============================] - 39s 51ms/step - loss: 1.1554 - acc: 0.7357 - val_loss: 2.6133 - val_acc: 0.5092
#
# Epoch 00008: val_acc did not improve from 0.69220
# Epoch 9/200
# 781/781 [==============================] - 40s 51ms/step - loss: 1.1563 - acc: 0.7444 - val_loss: 1.1600 - val_acc: 0.7460
#
# Epoch 00009: val_acc improved from 0.69220 to 0.74600, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 10/200
# 781/781 [==============================] - 39s 50ms/step - loss: 1.1536 - acc: 0.7428 - val_loss: 1.3825 - val_acc: 0.6520
#
# Epoch 00010: val_acc did not improve from 0.74600
# Epoch 11/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1487 - acc: 0.7450 - val_loss: 1.3715 - val_acc: 0.6950
#
# Epoch 00011: val_acc did not improve from 0.74600
# Epoch 12/200
# 781/781 [==============================] - 40s 51ms/step - loss: 1.1542 - acc: 0.7472 - val_loss: 1.5771 - val_acc: 0.6481
#
# Epoch 00012: val_acc did not improve from 0.74600
# Epoch 13/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1462 - acc: 0.7508 - val_loss: 1.5135 - val_acc: 0.6708
#
# Epoch 00013: val_acc did not improve from 0.74600
# Epoch 14/200
# 781/781 [==============================] - 40s 52ms/step - loss: 1.1475 - acc: 0.7513 - val_loss: 1.7816 - val_acc: 0.6033
#
# Epoch 00014: val_acc did not improve from 0.74600
# Epoch 15/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1429 - acc: 0.7540 - val_loss: 1.5313 - val_acc: 0.6540
#
# Epoch 00015: val_acc did not improve from 0.74600
# Epoch 16/200
# 781/781 [==============================] - 41s 52ms/step - loss: 1.1457 - acc: 0.7523 - val_loss: 2.0020 - val_acc: 0.6059
#
# Epoch 00016: val_acc did not improve from 0.74600
# Epoch 17/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.9269 - acc: 0.8121 - val_loss: 0.8903 - val_acc: 0.8108
#
# Epoch 00017: val_acc improved from 0.74600 to 0.81080, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 18/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.8369 - acc: 0.8184 - val_loss: 0.9177 - val_acc: 0.7872
#
# Epoch 00018: val_acc did not improve from 0.81080
# Epoch 19/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8133 - acc: 0.8184 - val_loss: 0.7867 - val_acc: 0.8302
#
# Epoch 00019: val_acc improved from 0.81080 to 0.83020, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 20/200
# 781/781 [==============================] - 39s 51ms/step - loss: 0.8064 - acc: 0.8202 - val_loss: 0.9365 - val_acc: 0.7902
#
# Epoch 00020: val_acc did not improve from 0.83020
# Epoch 21/200
# 781/781 [==============================] - 39s 50ms/step - loss: 0.8112 - acc: 0.8212 - val_loss: 0.9042 - val_acc: 0.8025
#
# Epoch 00021: val_acc did not improve from 0.83020
# Epoch 22/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8128 - acc: 0.8204 - val_loss: 0.9732 - val_acc: 0.7788
#
# Epoch 00022: val_acc did not improve from 0.83020
# Epoch 23/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.8065 - acc: 0.8245 - val_loss: 0.8615 - val_acc: 0.8076
#
# Epoch 00023: val_acc did not improve from 0.83020
# Epoch 24/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8066 - acc: 0.8249 - val_loss: 0.9145 - val_acc: 0.7978
#
# Epoch 00024: val_acc did not improve from 0.83020
# Epoch 25/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6905 - acc: 0.8608 - val_loss: 0.6726 - val_acc: 0.8618
#
# Epoch 00025: val_acc improved from 0.83020 to 0.86180, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 26/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6303 - acc: 0.8733 - val_loss: 0.6691 - val_acc: 0.8579
#
# Epoch 00026: val_acc did not improve from 0.86180
# Epoch 27/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.6016 - acc: 0.8743 - val_loss: 0.6499 - val_acc: 0.8539
#
# Epoch 00027: val_acc did not improve from 0.86180
# Epoch 28/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.5834 - acc: 0.8755 - val_loss: 0.6394 - val_acc: 0.8591
#
# Epoch 00028: val_acc did not improve from 0.86180
# Epoch 29/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.5747 - acc: 0.8756 - val_loss: 0.5943 - val_acc: 0.8725
#
# Epoch 00029: val_acc improved from 0.86180 to 0.87250, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 30/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5657 - acc: 0.8781 - val_loss: 0.6723 - val_acc: 0.8524
#
# Epoch 00030: val_acc did not improve from 0.87250
# Epoch 31/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5601 - acc: 0.8780 - val_loss: 0.6125 - val_acc: 0.8649
#
# Epoch 00031: val_acc did not improve from 0.87250
# Epoch 32/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.5612 - acc: 0.8790 - val_loss: 0.5953 - val_acc: 0.8695
#
# Epoch 00032: val_acc did not improve from 0.87250
# Epoch 33/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.5598 - acc: 0.8779 - val_loss: 0.6768 - val_acc: 0.8448
#
# Epoch 00033: val_acc did not improve from 0.87250
# Epoch 34/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.5612 - acc: 0.8772 - val_loss: 0.5947 - val_acc: 0.8728
#
# Epoch 00034: val_acc improved from 0.87250 to 0.87280, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 35/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.5604 - acc: 0.8763 - val_loss: 0.6100 - val_acc: 0.8666
#
# Epoch 00035: val_acc did not improve from 0.87280
# Epoch 36/200
# 781/781 [==============================] - 43s 54ms/step - loss: 0.4926 - acc: 0.9007 - val_loss: 0.5092 - val_acc: 0.8951
#
# Epoch 00036: val_acc improved from 0.87280 to 0.89510, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 37/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.4577 - acc: 0.9083 - val_loss: 0.4838 - val_acc: 0.8994
#
# Epoch 00037: val_acc improved from 0.89510 to 0.89940, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 38/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4397 - acc: 0.9124 - val_loss: 0.4932 - val_acc: 0.8948
#
# Epoch 00038: val_acc did not improve from 0.89940
# Epoch 39/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.4332 - acc: 0.9135 - val_loss: 0.4806 - val_acc: 0.8962
#
# Epoch 00039: val_acc did not improve from 0.89940
# Epoch 40/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.4206 - acc: 0.9167 - val_loss: 0.4794 - val_acc: 0.8985
#
# Epoch 00040: val_acc did not improve from 0.89940
# Epoch 41/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4102 - acc: 0.9167 - val_loss: 0.4677 - val_acc: 0.9025
#
# Epoch 00041: val_acc improved from 0.89940 to 0.90250, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 42/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.4104 - acc: 0.9160 - val_loss: 0.4640 - val_acc: 0.9008
#
# Epoch 00042: val_acc did not improve from 0.90250
# Epoch 43/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4001 - acc: 0.9186 - val_loss: 0.4588 - val_acc: 0.9021
#
# Epoch 00043: val_acc did not improve from 0.90250
# Epoch 44/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.3970 - acc: 0.9177 - val_loss: 0.4637 - val_acc: 0.9006
#
# Epoch 00044: val_acc did not improve from 0.90250
# Epoch 45/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.3916 - acc: 0.9186 - val_loss: 0.4486 - val_acc: 0.9065
#
# Epoch 00045: val_acc improved from 0.90250 to 0.90650, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 46/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.3934 - acc: 0.9170 - val_loss: 0.4960 - val_acc: 0.8888
#
# Epoch 00046: val_acc did not improve from 0.90650
# Epoch 47/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.3841 - acc: 0.9205 - val_loss: 0.4800 - val_acc: 0.8914
#
# Epoch 00047: val_acc did not improve from 0.90650
# Epoch 48/200
# 781/781 [==============================] - 43s 54ms/step - loss: 0.3802 - acc: 0.9210 - val_loss: 0.4688 - val_acc: 0.8980
#
# Epoch 00048: val_acc did not improve from 0.90650
# Epoch 49/200
# 781/781 [==============================] - 45s 58ms/step - loss: 0.3840 - acc: 0.9184 - val_loss: 0.4594 - val_acc: 0.8972
#
# Epoch 00049: val_acc did not improve from 0.90650
# Epoch 50/200
# 781/781 [==============================] - 50s 64ms/step - loss: 0.3804 - acc: 0.9186 - val_loss: 0.4426 - val_acc: 0.9025
#
# Epoch 00050: val_acc did not improve from 0.90650
# Epoch 51/200
# 781/781 [==============================] - 52s 67ms/step - loss: 0.3775 - acc: 0.9189 - val_loss: 0.4755 - val_acc: 0.8901
#
# Epoch 00051: val_acc did not improve from 0.90650
# Epoch 52/200
# 781/781 [==============================] - 52s 67ms/step - loss: 0.3781 - acc: 0.9193 - val_loss: 0.4664 - val_acc: 0.8976
#
# Epoch 00052: val_acc did not improve from 0.90650
# Epoch 53/200
# 781/781 [==============================] - 51s 65ms/step - loss: 0.3397 - acc: 0.9333 - val_loss: 0.4072 - val_acc: 0.9131
#
# Epoch 00053: val_acc improved from 0.90650 to 0.91310, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 54/200
# 781/781 [==============================] - 51s 65ms/step - loss: 0.3236 - acc: 0.9382 - val_loss: 0.4010 - val_acc: 0.9167
#
# Epoch 00054: val_acc improved from 0.91310 to 0.91670, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 55/200
# 781/781 [==============================] - 52s 67ms/step - loss: 0.3171 - acc: 0.9395 - val_loss: 0.4034 - val_acc: 0.9123
#
# Epoch 00055: val_acc did not improve from 0.91670
# Epoch 56/200
# 781/781 [==============================] - 50s 64ms/step - loss: 0.3117 - acc: 0.9411 - val_loss: 0.3880 - val_acc: 0.9194
#
# Epoch 00056: val_acc improved from 0.91670 to 0.91940, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 57/200
# 781/781 [==============================] - 44s 57ms/step - loss: 0.3047 - acc: 0.9423 - val_loss: 0.4004 - val_acc: 0.9157
#
# Epoch 00057: val_acc did not improve from 0.91940
# Epoch 58/200
# 781/781 [==============================] - 46s 59ms/step - loss: 0.3006 - acc: 0.9431 - val_loss: 0.4181 - val_acc: 0.9119
#
# Epoch 00058: val_acc did not improve from 0.91940
# Epoch 59/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.2982 - acc: 0.9431 - val_loss: 0.3948 - val_acc: 0.9176
#
# Epoch 00059: val_acc did not improve from 0.91940
# Epoch 60/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.3003 - acc: 0.9428 - val_loss: 0.3953 - val_acc: 0.9167
#
# Epoch 00060: val_acc did not improve from 0.91940
# Epoch 61/200
# 781/781 [==============================] - 43s 54ms/step - loss: 0.2929 - acc: 0.9449 - val_loss: 0.3925 - val_acc: 0.9164
#
# Epoch 00061: val_acc did not improve from 0.91940
# Epoch 62/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.2916 - acc: 0.9449 - val_loss: 0.3798 - val_acc: 0.9208
#
# Epoch 00062: val_acc improved from 0.91940 to 0.92080, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 63/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2857 - acc: 0.9473 - val_loss: 0.3924 - val_acc: 0.9144
#
# Epoch 00063: val_acc did not improve from 0.92080
# Epoch 64/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2864 - acc: 0.9459 - val_loss: 0.3935 - val_acc: 0.9161
#
# Epoch 00064: val_acc did not improve from 0.92080
# Epoch 65/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2819 - acc: 0.9470 - val_loss: 0.3846 - val_acc: 0.9155
#
# Epoch 00065: val_acc did not improve from 0.92080
# Epoch 66/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2771 - acc: 0.9465 - val_loss: 0.3865 - val_acc: 0.9163
#
# Epoch 00066: val_acc did not improve from 0.92080
# Epoch 67/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2759 - acc: 0.9477 - val_loss: 0.3878 - val_acc: 0.9162
#
# Epoch 00067: val_acc did not improve from 0.92080
# Epoch 68/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2767 - acc: 0.9470 - val_loss: 0.3911 - val_acc: 0.9120
#
# Epoch 00068: val_acc did not improve from 0.92080
# Epoch 69/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2634 - acc: 0.9526 - val_loss: 0.3723 - val_acc: 0.9182
#
# Epoch 00069: val_acc did not improve from 0.92080
# Epoch 70/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.2597 - acc: 0.9522 - val_loss: 0.3762 - val_acc: 0.9158
#
# Epoch 00070: val_acc did not improve from 0.92080
# Epoch 71/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2554 - acc: 0.9539 - val_loss: 0.3696 - val_acc: 0.9206
#
# Epoch 00071: val_acc did not improve from 0.92080
# Epoch 72/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.2533 - acc: 0.9552 - val_loss: 0.3705 - val_acc: 0.9181
#
# Epoch 00072: val_acc did not improve from 0.92080
# Epoch 73/200
# 781/781 [==============================] - 45s 58ms/step - loss: 0.2500 - acc: 0.9550 - val_loss: 0.3670 - val_acc: 0.9197
#
# Epoch 00073: val_acc did not improve from 0.92080
# Epoch 74/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.2471 - acc: 0.9570 - val_loss: 0.3694 - val_acc: 0.9200
#
# Epoch 00074: val_acc did not improve from 0.92080
# Epoch 75/200
# 781/781 [==============================] - 43s 55ms/step - loss: 0.2461 - acc: 0.9573 - val_loss: 0.3643 - val_acc: 0.9202
#
# Epoch 00075: val_acc did not improve from 0.92080
# Epoch 76/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2443 - acc: 0.9571 - val_loss: 0.3680 - val_acc: 0.9203
#
# Epoch 00076: val_acc did not improve from 0.92080
# Epoch 77/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2425 - acc: 0.9573 - val_loss: 0.3634 - val_acc: 0.9211
#
# Epoch 00077: val_acc improved from 0.92080 to 0.92110, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 78/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.2424 - acc: 0.9567 - val_loss: 0.3758 - val_acc: 0.9167
#
# Epoch 00078: val_acc did not improve from 0.92110
# Epoch 79/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.2411 - acc: 0.9573 - val_loss: 0.3619 - val_acc: 0.9214
#
# Epoch 00079: val_acc improved from 0.92110 to 0.92140, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 80/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.2391 - acc: 0.9580 - val_loss: 0.3622 - val_acc: 0.9198
#
# Epoch 00080: val_acc did not improve from 0.92140
# Epoch 81/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.2387 - acc: 0.9585 - val_loss: 0.3621 - val_acc: 0.9201
#
# Epoch 00081: val_acc did not improve from 0.92140
# Epoch 82/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2342 - acc: 0.9600 - val_loss: 0.3615 - val_acc: 0.9215
#
# Epoch 00082: val_acc improved from 0.92140 to 0.92150, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 83/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2337 - acc: 0.9608 - val_loss: 0.3611 - val_acc: 0.9203
#
# Epoch 00083: val_acc did not improve from 0.92150
# Epoch 84/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2343 - acc: 0.9599 - val_loss: 0.3608 - val_acc: 0.9217
#
# Epoch 00084: val_acc improved from 0.92150 to 0.92170, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 85/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2358 - acc: 0.9597 - val_loss: 0.3615 - val_acc: 0.9208
#
# Epoch 00085: val_acc did not improve from 0.92170
# Epoch 86/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2351 - acc: 0.9597 - val_loss: 0.3609 - val_acc: 0.9206
#
# Epoch 00086: val_acc did not improve from 0.92170
# Epoch 87/200
# 781/781 [==============================] - 42s 53ms/step - loss: 0.2326 - acc: 0.9624 - val_loss: 0.3605 - val_acc: 0.9210
#
# Epoch 00087: val_acc did not improve from 0.92170
# Epoch 88/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.2311 - acc: 0.9615 - val_loss: 0.3608 - val_acc: 0.9217
#
# Epoch 00088: val_acc did not improve from 0.92170
# Epoch 89/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2328 - acc: 0.9602 - val_loss: 0.3611 - val_acc: 0.9214
#
# Epoch 00089: val_acc did not improve from 0.92170
# Epoch 90/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2315 - acc: 0.9603 - val_loss: 0.3601 - val_acc: 0.9218
#
# Epoch 00090: val_acc improved from 0.92170 to 0.92180, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 91/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2350 - acc: 0.9592 - val_loss: 0.3602 - val_acc: 0.9219
#
# Epoch 00091: val_acc improved from 0.92180 to 0.92190, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 92/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2314 - acc: 0.9605 - val_loss: 0.3594 - val_acc: 0.9218
#
# Epoch 00092: val_acc did not improve from 0.92190
# Epoch 93/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2306 - acc: 0.9604 - val_loss: 0.3594 - val_acc: 0.9216
#
# Epoch 00093: val_acc did not improve from 0.92190
# Epoch 94/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2294 - acc: 0.9606 - val_loss: 0.3603 - val_acc: 0.9209
#
# Epoch 00094: val_acc did not improve from 0.92190
# Epoch 95/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2305 - acc: 0.9611 - val_loss: 0.3601 - val_acc: 0.9210
#
# Epoch 00095: val_acc did not improve from 0.92190
# Epoch 96/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2323 - acc: 0.9604 - val_loss: 0.3595 - val_acc: 0.9216
#
# Epoch 00096: val_acc did not improve from 0.92190
# Epoch 97/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2285 - acc: 0.9619 - val_loss: 0.3583 - val_acc: 0.9219
#
# Epoch 00097: val_acc did not improve from 0.92190
# Epoch 98/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2298 - acc: 0.9611 - val_loss: 0.3599 - val_acc: 0.9215
#
# Epoch 00098: val_acc did not improve from 0.92190
# Epoch 99/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2298 - acc: 0.9616 - val_loss: 0.3591 - val_acc: 0.9220
#
# Epoch 00099: val_acc improved from 0.92190 to 0.92200, saving model to ./Model_trained/WideResNet20_cifar10.h5
# Epoch 100/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2290 - acc: 0.9616 - val_loss: 0.3592 - val_acc: 0.9216
#
# Epoch 00100: val_acc did not improve from 0.92200
# Epoch 101/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2302 - acc: 0.9618 - val_loss: 0.3601 - val_acc: 0.9211
#
# Epoch 00101: val_acc did not improve from 0.92200
# Epoch 102/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2290 - acc: 0.9614 - val_loss: 0.3601 - val_acc: 0.9208
#
# Epoch 00102: val_acc did not improve from 0.92200
# Epoch 103/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2303 - acc: 0.9606 - val_loss: 0.3588 - val_acc: 0.9208
#
# Epoch 00103: val_acc did not improve from 0.92200
# Epoch 104/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2313 - acc: 0.9603 - val_loss: 0.3590 - val_acc: 0.9212
#
# Epoch 00104: val_acc did not improve from 0.92200
# Epoch 105/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2299 - acc: 0.9618 - val_loss: 0.3595 - val_acc: 0.9217
#
# Epoch 00105: val_acc did not improve from 0.92200
# Epoch 106/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2307 - acc: 0.9618 - val_loss: 0.3594 - val_acc: 0.9217
#
# Epoch 00106: val_acc did not improve from 0.92200
# Epoch 107/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2315 - acc: 0.9602 - val_loss: 0.3591 - val_acc: 0.9215
#
# Epoch 00107: val_acc did not improve from 0.92200
# Epoch 108/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2332 - acc: 0.9592 - val_loss: 0.3596 - val_acc: 0.9205
#
# Epoch 00108: val_acc did not improve from 0.92200
# Epoch 109/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2318 - acc: 0.9602 - val_loss: 0.3592 - val_acc: 0.9215
#
# Epoch 00109: val_acc did not improve from 0.92200
# Epoch 110/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.2342 - acc: 0.9592 - val_loss: 0.3585 - val_acc: 0.9219
#
# Epoch 00110: val_acc did not improve from 0.92200
# Epoch 111/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2303 - acc: 0.9615 - val_loss: 0.3590 - val_acc: 0.9215
#
# Epoch 00111: val_acc did not improve from 0.92200
# Epoch 112/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2300 - acc: 0.9608 - val_loss: 0.3604 - val_acc: 0.9209
#
# Epoch 00112: val_acc did not improve from 0.92200
# Epoch 113/200
# 781/781 [==============================] - 40s 52ms/step - loss: 0.2292 - acc: 0.9612 - val_loss: 0.3601 - val_acc: 0.9212
#
# Epoch 00113: val_acc did not improve from 0.92200
# Epoch 114/200
# 781/781 [==============================] - 42s 54ms/step - loss: 0.2311 - acc: 0.9611 - val_loss: 0.3591 - val_acc: 0.9218
#
# Epoch 00114: val_acc did not improve from 0.92200
# Epoch 115/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2314 - acc: 0.9608 - val_loss: 0.3596 - val_acc: 0.9213
#
# Epoch 00115: val_acc did not improve from 0.92200
# Epoch 116/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2280 - acc: 0.9624 - val_loss: 0.3601 - val_acc: 0.9211
#
# Epoch 00116: val_acc did not improve from 0.92200
# Epoch 117/200
# 781/781 [==============================] - 41s 52ms/step - loss: 0.2331 - acc: 0.9600 - val_loss: 0.3597 - val_acc: 0.9216
#
# Epoch 00117: val_acc did not improve from 0.92200
# Epoch 118/200
# 781/781 [==============================] - 41s 53ms/step - loss: 0.2321 - acc: 0.9607 - val_loss: 0.3595 - val_acc: 0.9214
#
# Epoch 00118: val_acc did not improve from 0.92200
# Epoch 119/200
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2304 - acc: 0.9610 - val_loss: 0.3591 - val_acc: 0.9218
#
# Epoch 00119: val_acc did not improve from 0.92200
# Total training time : 4991.425 s

# %% [markdown]
# # Final evaluation

# %%
best_model = keras.models.load_model(save_path)
print('Best model test accuracy :', best_model.evaluate(x_test, y_test, batch_size=64)[1])
# Out:
# 10000/10000 [==============================] - 4s 353us/step
# Best model test accuracy : 0.922

# %% [markdown]
# # Conclusion
#
# Reducing the number of $3*3$ convolutional layers from 18 to 12 and doubling the number of kernels, coupled with the addition of dropout, has proved to be an effective way to improve accuracy (by aproximately $1 \%$). The cost to pay is a significant increase in parameters, but dispite that, the computational time for each trainig steps remained similar.
